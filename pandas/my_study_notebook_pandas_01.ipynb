# %% [markdown]
# # Trabalhando com Grandes Arquivos

# %%
import pandas as pd
arquivo = 'kc_house_data.csv'

# %%
#Lendo as 5 primeiras linhas do arquivo.
#   --nrows='n'--
dataset = pd.read_csv(arquivo, sep=',')

# %%
#O dataframe dataset, tem somente 5 linhas que foram carregadas pelo metodo 'nrows'
dataset.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000   538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000   180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000   604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000   510000.0       3.0       2.00         1680
# 5  7237550310  20140512T000000  1225000.0       4.0       4.50         5420
# 6  1321400060  20140627T000000   257500.0       3.0       2.25         1715
# 7  2008000270  20150115T000000   291850.0       3.0       1.50         1060
# 8  2414600126  20150415T000000   229500.0       3.0       1.00         1780
# 9  3793500160  20150312T000000   323000.0       3.0       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
#Ultilizando o parametro chunksize podemos definir um bloco de dados com uma determinada quantidade de linhas
chunk = pd.read_csv(arquivo, chunksize=10000)

# %%
type(chunk)
# Out:
# pandas.io.parsers.TextFileReader

# %%
#Imprimindo a quantidade de linhas em cada bloco
for parte in chunk:
    print (len(parte))
# Out:
# 10000
# 10000
# 1613

# %%
chunk = pd.read_csv(arquivo, chunksize=10000)

# %%
#Nesse bloco de condigo, crio uma lista que irá receber os elemento de 'bedrooms' e muiltiplico por 2,
#adiciono com o metodo --append-- no final da lista.
#Na ultima linha crio uma nova coluna chamada 'bedrooms_size' e com o metodo --concat()-- adiciono os dados
#de lista em a nova coluna 'bedrooms' do meu dataset.
lista = []
for partes in chunk:
    lista.append(partes['bedrooms'] * 2)
    
dataset['bedrooms_size'] = pd.concat(lista)

# %%
dataset
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# ...

# %% [markdown]
# # Mais recurso para trabalhar com grandes bases de dados

# %% [markdown]
# 1. Tente trabalhar apenas com as colunas que você vai realmente precisar.
# 2. Atente para o tipo de dado de cada cluna.
# 3. Visualizar qual o separador usado para separar os dados.
#
# Dica: Se estiver no linux use o comando head para ler as 5 primeiras linas do arquivo:
#  head -m 5 dataset.csv

# %%
#Fazendo uma Lista com as colunas de um dataframe utilizando o metodo tolist()
#   --tolist()-- ele transforma a entrada em uma lista e retorna a lista.

dataset.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
#Usando a saida do --tolist()-- como paramentro para usecols=['colunas']
df =  pd.read_csv('kc_house_data.csv', usecols=['id',
 'date',
 'price',
 'bedrooms',
 'bathrooms',
 'sqft_living',
 'sqft_lot',
 'floors',
 'waterfront',
 'view'], sep=',')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view
# 0      5650     1.0           0     0
# 1      7242     2.0           0     0
# 2     10000     1.0           0     0
# 3      5000     1.0           0     0
# 4      8080     1.0           0     0

# %%
#Com o metodo usecols='[1,2,3,4]' podemos escolher as colunas por sua posição numericamente

df = pd.read_csv('kc_house_data.csv', usecols=[1,2,3,4])

# %%
df.head()
# Out:
#               date     price  bedrooms  bathrooms
# 0  20141013T000000  221900.0       3.0       1.00
# 1  20141209T000000  538000.0       3.0       2.25
# 2  20150225T000000  180000.0       2.0       1.00
# 3  20141209T000000  604000.0       4.0       3.00
# 4  20150218T000000  510000.0       3.0       2.00

# %%
#Vendo informações de tamanhos do Dataframe para validar a utilização da quantidade de memoria
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
# date         21613 non-null object
# price        21613 non-null float64
# bedrooms     21609 non-null float64
# bathrooms    21613 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 675.5+ KB

# %%
#Lendo todas as colunas exetos algumas com a expressão abaixo
data = 'kc_house_data.csv'
df = pd.read_csv(data, usecols = lambda column : column not in ['date'])

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0       3.0       1.00         1180      5650     1.0
# 1  6414100192  538000.0       3.0       2.25         2570      7242     2.0
# 2  5631500400  180000.0       2.0       1.00          770     10000     1.0
# 3  2487200875  604000.0       4.0       3.00         1960      5000     1.0
# 4  1954400510  510000.0       3.0       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %% [markdown]
# # Trabalhando com os tipos de dados adequados

# %% [markdown]
# * Atenção para os tipos de object
# * Dados que são categoricos podem receber o tipo de dados caregory

# %%
#Carregando uma base da web
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
#Verificando o tamanha da memoria do dataframe com o metodo --.info()--
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#convetendo os tipo de dados
df.Sex = df.Sex.astype('category')
df.Embarked = df.Embarked.astype('category')
df.Survived = df.Survived.astype('category')
df.Pclass = df.Pclass.astype('category')
df.PassengerId = df.PassengerId.astype('int32')
df.Parch = df.Parch.astype('int32')
df.SibSp = df.SibSp.astype('int32')

# %%
#Vendo as mudanças no consumo de memoria do Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int32
# Survived       891 non-null category
# Pclass         891 non-null category
# Name           891 non-null object
# Sex            891 non-null category
# Age            714 non-null float64
# SibSp          891 non-null int32
# Parch          891 non-null int32
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null category
# dtypes: category(4), float64(2), int32(3), object(3)
# memory usage: 49.2+ KB

# %%
#Convertendo os valores na leitura do datase
data = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(data, dtype = {"Embarked" : "category", "Survived" : "category", "Parch" : "int32"})

# %%
#Vendo as mudanças com o df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null category
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int32
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null category
# dtypes: category(2), float64(2), int32(1), int64(3), object(4)
# memory usage: 68.1+ KB

# %% [markdown]
# # Consultando um Dataset

# %% [markdown]
# * Podemos fazer conultas em Dataframe isso se assemelha a linha SQL.
# * As consultas podem ser feitas por instruções de agrupamentos

# %%
#Contar a quantidade de valores unicos
pd.value_counts(dataset['bedrooms'])
# Out:
# 3.0     9822
# 4.0     6881
# 2.0     2759
# 5.0     1601
# 6.0      272
# 1.0      199
# 7.0       38
# 8.0       13
# 9.0        6
# 10.0       3
# 11.0       1
# Name: bedrooms, dtype: int64

# %%
#Consultando os número de imoveis que tem a quantidade de quartos iguais a 3
#Usando o metodo --.loc[lista]---, O metodo loc recerbe uuma lista como parametro
dataset.loc[dataset['bedrooms']==3]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# 6      1321400060  20140627T000000  257500.0       3.0       2.25
# 7      2008000270  20150115T000000  291850.0       3.0       1.50
# ...           ...              ...       ...       ...        ...
# 21603  7852140040  20140825T000000  507250.0       3.0       2.50
# 21604  9834201367  20150126T000000  429000.0       3.0       2.00
# 21607  2997800021  20150219T000000  475000.0       3.0       2.50
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
#É possivel com o metodo loc fazer buscas com operadores logicos como exemplo a baixo
#--.loc[(dataset['coluna'] ==1)&(dataset['coluna']==2)]
dataset.loc[(dataset['bedrooms']==3) & (dataset['bathrooms']==3)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 284    5634500392  20150410T000000  330000.0       3.0        3.0
# 377    1545804860  20141027T000000  275000.0       3.0        3.0
# 381     624111000  20140805T000000  950000.0       3.0        3.0
# 457    2122039094  20141126T000000  705000.0       3.0        3.0
# 482    6189200125  20150325T000000  849950.0       3.0        3.0
# ...           ...              ...       ...       ...        ...
# 21417  5693501102  20141030T000000  598500.0       3.0        3.0
# 21457  3629700120  20141014T000000  669950.0       3.0        3.0
# 21574  1931300090  20140507T000000  610950.0       3.0        3.0
# 21580  7853420110  20141003T000000  594866.0       3.0        3.0
# 21581  7853420110  20150504T000000  625000.0       3.0        3.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 284           2420     13959     1.0           0     0  ...      8
# ...

# %%
#Ordenando o dataset pela coluna price do maior para o menos com o metodo sort_values()
#--.sort_values(by='price', ascending=False)

dataset.sort_values(by='price', ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0       6.0       8.00
# 3914   9808700762  20140611T000000  7062500.0       5.0       4.50
# 9254   9208900037  20140919T000000  6885000.0       6.0       7.75
# 4411   2470100110  20140804T000000  5570000.0       5.0       5.75
# 1448   8907500070  20150413T000000  5350000.0       5.0       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0       3.0       1.00
# 16198  3028200080  20150324T000000    81000.0       2.0       1.00
# 465    8658300340  20140523T000000    80000.0       1.0       0.75
# 15293    40000362  20140506T000000    78000.0       2.0       1.00
# 1149   3421079032  20150217T000000    75000.0       1.0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %%
#Contando todas as linhas que tem o numero de bedrooms igual a 4
#dataset[lista['name_colum']==4].count()

dataset[dataset['bedrooms']==4].count()
# Out:
# id               6881
# date             6881
# price            6881
# bedrooms         6881
# bathrooms        6881
# sqft_living      6881
# sqft_lot         6881
# floors           6881
# waterfront       6881
# view             6881
# condition        6881
# grade            6881
# sqft_above       6881
# sqft_basement    6881
# yr_built         6881
# yr_renovated     6881
# zipcode          6881
# lat              6881
# long             6881
# sqft_living15    6881
# sqft_lot15       6881
# dtype: int64

# %% [markdown]
# # Alterando um Dataframe

# %%
#Criando uma nova coluna e adicionando valores com uma calculo matematico
dataset['size'] = (dataset['bedrooms'] * 20)

# %%
#Visualizando o contúdo de uma coluna
dataset['size'].head()
# Out:
# 0    60.0
# 1    60.0
# 2    40.0
# 3    80.0
# 4    60.0
# Name: size, dtype: float64

# %%
#Criando uma função para processamento de dados
def categoriza(x):
    if x >= 80:
        return 'Big'
    elif x >= 60:
        return 'Medium'
    elif x >= 40:
        return 'small'

# %%
#Usando uma função para categorizar os imoveis
#Criando uma lista = aplincando a função na coluna size
dataset['cat_size'] = (dataset['size'].apply(categoriza))

# %%
#Mostrando a coluna cat_size
dataset['cat_size']
# Out:
# 0        Medium
# 1        Medium
# 2         small
# 3           Big
# 4        Medium
#           ...
# 21608    Medium
# 21609       Big
# 21610     small
# 21611    Medium
# 21612     small
# Name: cat_size, Length: 21613, dtype: object

# %%
#Verificando a quantidade de valores de cada categoria
#Usando o metodo --pd.value_counts(lista)
pd.value_counts(dataset['cat_size'])
# Out:
# Medium    9822
# Big       8816
# small     2759
# Name: cat_size, dtype: int64

# %%
#Apagando dados do dataset
#axis=1 apaga uma coluna
#axis=0 apaga uma linha
#inplace=True salva as alterações em memoria
#inplace=False não salva as alterações em memoria

dataset.drop(['cat_size'], axis=1, inplace=True)

# %%
#Verificando a coluna cat_size
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#Apagando linhas como especificações logicas
dataset.drop(dataset[dataset.bedrooms==0].index, inplace=True)

# %%
#O codigo a baixo mostra que nao tem nem uma valor 0 na coluna bedrooms
pd.value_counts(dataset['bedrooms']==0)
# Out:
# False    21600
# Name: bedrooms, dtype: int64

# %%
dataset.drop(dataset[dataset.bedrooms>30].index, inplace=True)
