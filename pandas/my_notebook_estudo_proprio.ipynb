# %%
import pandas as pd
import sqlalchemy

# %%
# !pip install pymysql

# %%
# Engine de conexão

engine = sqlalchemy.create_engine('mysql+pymysql://root:Salmos4;1@localhost:3306/sucos_vendas')

# %%
# Fazendo consulta de tabelas

df = pd.read_sql_table('tabela_de_clientes', engine)

# %%
df.head()
# Out:
#            CPF                 NOME                            ENDERECO_1  \
# 0   1471156710       Érica Carvalho                          R. Iriquitia
# 1  19290992743  Fernando Cavalcante                  R. Dois de Fevereiro
# 2   2600586709       César Teixeira                   Rua Conde de Bonfim
# 3   3623344710     Marcos Nougeuira  Av. Pastor Martin Luther King Junior
# 4    492472718        Eduardo Jorge                       R. Volta Grande
#
#   ENDERECO_2      BAIRRO          CIDADE ESTADO       CEP DATA_DE_NASCIMENTO  \
# 0                Jardins       São Paulo     SP  80012212         1990-09-01
# 1             Água Santa  Rio de Janeiro     RJ  22000000         2000-02-12
# 2                 Tijuca  Rio de Janeiro     RJ  22020001         2000-03-12
# 3                Inhauma  Rio de Janeiro     RJ  22002012         1995-01-13
# 4                 Tijuca  Rio de Janeiro     RJ  22012002         1994-07-19
#
# ...

# %%
df = pd.read_sql_table('tabela_de_clientes', engine, columns=["NOME","CPF"])

# %%
df.head(10)
# Out:
#                   NOME          CPF
# 0       Érica Carvalho   1471156710
# 1  Fernando Cavalcante  19290992743
# 2       César Teixeira   2600586709
# 3     Marcos Nougeuira   3623344710
# 4        Eduardo Jorge    492472718
# 5          Abel Silva   50534475787
# 6       Petra Oliveira   5576228758
# 7   Paulo César Mattos   5648641702
# 8       Gabriel Araujo   5840119709
# 9       Marcelo Mattos   7771579779
